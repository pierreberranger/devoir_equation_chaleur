# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd

# %%
f = open("temperature.txt","r")
L = []
for x in  f:
    L.append([float(el) for el in x.split()])
plt.plot
for el in L:
    plt.plot(el)
