# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Euler explicite

# %%
f = open("temperature_explicite_homogene.txt","r")
L = []
for x in  f:
    L.append([float(el) for el in x.split()])

for el in L:
    plt.plot(el)

# %% [markdown]
# ## Euler Implicite

# %%
f = open("temperature_implicite_homogene.txt","r")
L = []
for x in  f:
    L.append([float(el) for el in x.split()])

for el in L:
    plt.plot(el)

# %% [markdown]
# ## Cas avec variation du coéfficient de diffusion

# %% [markdown]
# ### Euler Explicite

# %%
f = open("temperature_explicite_heterogene.txt","r")
L = []
for x in  f:
    L.append([float(el) for el in x.split()])

for el in L:
    plt.plot(el)

# %% [markdown]
# ### Euler Implicite

# %%
f = open("temperature_implicite_heterogene.txt","r")
L = []
for x in  f:
    L.append([float(el) for el in x.split()])

for el in L:
    plt.plot(el)
